# %% [markdown]
# <a href="https://colab.research.google.com/github/S10143806H/DimRed/blob/master/hw_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

def g(x):
  return 50 + 30 * np.exp(-100 * x)

def f(x):
  return 120 * x + (1 - x) * g(x)

def normalize_f(f_x):
  # subtract the minimum value from f_x
  f_x = f_x - np.min(f_x)
  # divide f_x by the maximum value
  f_x = f_x / np.max(f_x)
  # return the normalized f_x
  return f_x

x = np.linspace(0, 0.33, 100)
g_x = g(x)
f_x = f(x)
f_star_x = normalize_f(f_x)

plt.plot(x, g_x, label="g(x)")
plt.plot(x, f_x, label="f(x)")
plt.xlabel("x")
plt.ylabel("g(x), f(x)")
plt.title("g(x)=50+30e^(-100x), f(x)=120x+(1-x)g(x)")
plt.legend()
plt.show()

# generate random 20 points for x
x = np.linspace(0, 0.33, 20)
x = np.around(x, decimals=3)
g_x = g(x)
f_x = f(x)

print("x")
print(x)
print("------------------------------------------------")
print("g_x")
print(g_x)
print("------------------------------------------------")
print("f_x")
print(f_x)
print("------------------------------------------------")

# normalize f(x)
f_star_x = normalize_f(f_x)
plt.plot(x, f_star_x, label="f*(x)")
plt.xlabel("x")
plt.ylabel("f*(x)")
plt.title("f*(x)")
plt.legend()
plt.show()
print(f_star_x)
# Out:
# x
# [0.    0.017 0.035 0.052 0.069 0.087 0.104 0.122 0.139 0.156 0.174 0.191
#  0.208 0.226 0.243 0.261 0.278 0.295 0.313 0.33 ]
# ------------------------------------------------
# g_x
# [80.         55.48050572 50.9059215  50.16549693 50.03023356 50.00499757
#  50.00091297 50.00015091 50.00002757 50.00000504 50.00000083 50.00000015
#  50.00000003 50.         50.         50.         50.         50.
#  50.         50.        ]
# ------------------------------------------------
# f_x
# [80.         56.57733712 53.32421425 53.79689109 54.85814745 56.09456279
#  57.28081803 58.5401325  59.73002374 60.92000425 62.18000069 63.37000012
#  64.56000002 65.82       67.01       68.27       69.46       70.65
#  71.91       73.1       ]
# ------------------------------------------------
# [1.         0.1219504  0.         0.01771932 0.05750283 0.10385256
#  0.14832192 0.19553007 0.24013574 0.28474475 0.33197847 0.37658819
#  0.42119793 0.46843178 0.51304152 0.56027537 0.60488512 0.64949486
# ...
