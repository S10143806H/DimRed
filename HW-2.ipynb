# %% [markdown]
# <a href="https://colab.research.google.com/github/S10143806H/DimRed/blob/master/HW-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

def g(x):
  return 50 + 30 * np.exp(-100 * x)

def f(x):
  return 120 * x + (1 - x) * g(x)

def normalize_f(f_x):
  # subtract the minimum value from f_x
  f_x = f_x - np.min(f_x)
  # divide f_x by the maximum value
  f_x = f_x / np.max(f_x)
  # return the normalized f_x
  return f_x

x = np.linspace(0, 1, 100)
g_x = g(x)
f_x = f(x)
f_star_x = normalize_f(f_x)

plt.plot(x, g_x, label="g(x)")
plt.plot(x, f_x, label="f(x)")
plt.xlabel("x")
plt.ylabel("g(x), f(x)")
plt.title("g(x)=50+30e^(-100x), f(x)=120x+(1-x)g(x)")
plt.legend()
plt.show()

# generate random 20 points for x
x = np.linspace(0, 1, 20)
x = np.around(x, decimals=3)
g_x = g(x)
f_x = f(x)

print("x")
print(x)
print("------------------------------------------------")
print("g_x")
print(g_x)
print("------------------------------------------------")
print("f_x")
print(f_x)
print("------------------------------------------------")

# normalize f(x)
f_star_x = normalize_f(f_x)
plt.plot(x, f_star_x, label="f*(x)")
plt.xlabel("x")
plt.ylabel("f*(x)")
plt.title("f*(x)")
plt.legend()
plt.show()
print(f_star_x)
# Out:
# x
# [0.    0.053 0.105 0.158 0.211 0.263 0.316 0.368 0.421 0.474 0.526 0.579
#  0.632 0.684 0.737 0.789 0.842 0.895 0.947 1.   ]
# ------------------------------------------------
# g_x
# [80.         50.14974782 50.00082609 50.00000412 50.00000002 50.
#  50.         50.         50.         50.         50.         50.
#  50.         50.         50.         50.         50.         50.
#  50.         50.        ]
# ------------------------------------------------
# f_x
# [ 80.          53.85181118  57.35073935  61.06000347  64.77000002
#   68.41        72.12        75.76        79.47        83.18
#   86.82        90.53        94.24        97.88       101.59
#  105.23       108.94       112.65       116.29       120.        ]
# ------------------------------------------------
# [0.39529712 0.         0.0528953  0.10897037 0.1650565  0.22008447
#  0.27617066 0.33119862 0.38728481 0.443371   0.49839896 0.55448516
#  0.61057135 0.66559931 0.7216855  0.77671346 0.83279965 0.88888585
#  0.94391381 1.        ]
